# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
rd = np.random.random(100)

file_name = 'simple_data.txt'
with open(file_name, 'w') as f:
    f.write(str(rd))

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
rd_matrix = np.random.random(25).reshape(5,5)

file_name = 'data.txt'
with open(file_name, 'w') as f:
    f.write(str(rd_matrix))

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
file_name = 'data.txt'
with open(file_name, 'r') as f:
    lines = f.readlines()

new_lines = []
for line in lines:
    line = line.replace('[', '').replace(']','').strip()
    line = line.split()
    new_lines.append(','.join(line))

with open(file_name, "w") as f:
    f.write("\n".join(new_lines))
    
os.rename(file_name, 'data.csv')

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
file_name = 'credit_card.dat'

with open(file_name, 'r') as f:
    lines = f.readlines()

number_cards = []
for line in lines:
    line = line.strip()
    length = len(line)
    num = int(line, 2)

    total_numbers = length // 6 
    numbers = []

    for i in range(total_numbers):
        shift = length - (i+1)*6
        mask = 0x3F
        bin_num = (num >> shift) & mask
        numbers.append(chr(bin_num))

    number_cards.append(numbers)
    
print(number_cards)
# Out:
# [['7', '6', '4', '8', ' ', '5', '6', '7', '3', ' ', '3', '7', '7', '5', ' ', '2', '2', '7', '1'], ['3', '2', '5', '7', ' ', '8', '2', '4', '7', ' ', '3', '3', '5', '4', ' ', '2', '2', '6', '6'], ['2', '7', '2', '2', ' ', '0', '0', '0', '1', ' ', '4', '0', '1', '1', ' ', '6', '6', '5', '2'], ['0', '6', '6', '1', ' ', '3', '0', '6', '3', ' ', '3', '7', '4', '2', ' ', '3', '1', '5', '0'], ['0', '4', '3', '2', ' ', '1', '6', '0', '8', ' ', '1', '4', '6', '2', ' ', '4', '7', '4', '2'], ['5', '8', '2', '7', ' ', '2', '0', '2', '7', ' ', '8', '7', '8', '5', ' ', '7', '3', '0', '3'], ['5', '7', '7', '4', ' ', '8', '5', '2', '8', ' ', '2', '0', '8', '7', ' ', '1', '1', '1', '7'], ['8', '1', '4', '0', ' ', '1', '2', '1', '0', ' ', '6', '3', '5', '2', ' ', '2', '8', '4', '5'], ['5', '7', '6', '4', ' ', '1', '1', '3', '3', ' ', '7', '3', '0', '1', ' ', '7', '1', '0', '0'], ['6', '4', '5', '6', ' ', '1', '7', '3', '7', ' ', '4', '1', '2', '6', ' ', '6', '7', '2', '6'], ['1', '2', '2', '8', ' ', '
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json

data = json.load(open('user_data.json'))
people_and_cardtypes = [[person['FirstNameLastName'], person['CreditCardType']] for person in data]

people_with_AmericanExpress = []
for i in range(len(people_and_cardtypes)):
    if people_and_cardtypes[i][1] == 'American Express': people_with_AmericanExpress.append(people_and_cardtypes[i][0])

print(people_with_AmericanExpress)
# Out:
# ['Clint Thorpe', 'Phillip Carpenter', 'Russel Graves', 'Leanne Newton', 'Tony Giles', 'Owen Allcott', 'Liam Lynn', 'Regina Woodcock', 'Carter Wallace', 'Maia Stark', 'Ciara Lomax', 'Isabel Ellwood', 'Abdul Townend', 'Caleb Poulton', 'Ronald Lewis', 'Faith Seymour', 'Anthony Hancock', 'Isabella Willson', 'Stephanie Darcy', 'Ryan Kennedy']

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
csv_path = 'https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'

df = pd.read_csv(csv_path)

import matplotlib.pyplot as plt
plt.hist(df['class'])
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
csv_path = 'https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1'

df = pd.read_csv(csv_path)

plt, ax = plt.subplots(3,1)
ax[0].scatter(df['label'], df['features_1'])
ax[1].scatter(df['label'], df['features_2'])
ax[2].scatter(df['label'], df['features_3'])

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
csv_path = 'https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'

df = pd.read_csv(csv_path)
df.to_json()

print(df)
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...
