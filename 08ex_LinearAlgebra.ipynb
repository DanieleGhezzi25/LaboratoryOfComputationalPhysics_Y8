# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np
import scipy.linalg as la
import matplotlib.pyplot as plt

N = 1000
x1 = np.random.normal(loc=0, scale=1, size=N)
x2 = x1 + np.random.normal(loc=0, scale=3, size=N)
x3 = 2*x1 + x2

X = np.column_stack((x1, x2, x3))
X = X - np.mean(X, axis=0) # center the data on zero

# cov matrix
cov1 = np.cov(X, rowvar=False)
l1, V1 = la.eig(cov1)
l1 = np.sort(l1)
print(l1)
print(cov1, '\n')

# svd
U, sigma, Vt = la.svd(X)
l2 = np.sort((sigma**2)/(N-1))
print(l2)
cov2 = (Vt.T @ np.diag(sigma).T @ np.diag(sigma) @ Vt)/(N-1) # cov matrix via SVD (V D^T D V^T = X^T X)
print(cov2, '\n')

np.allclose(l1,l2)

# variability and dimensionality reduction
# we want to retain 99% of variance! so we find the features whose variance is negligible, such that the tot variance is above 99%
cov_trace = np.sum(l2)
variability = l2/cov_trace
tot_variability = np.cumsum(variability)
print(f'Variability: {variability}')
print(f'From this it is clear that we have to remove the first entry to retain the 99% of total variance while we remove this feature \n')

V_reduced = Vt[:2, :] # the V eigenvectors are sorted from the highest eigenvalue to the lowest
X_reduced = X @ V_reduced.T

print(X_reduced)

# plots
X_reduced4plots = np.hstack((X_reduced, np.zeros((N,1))))

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(14,10))

pairs = [(0,1), (0,2), (1,2)]
labels = ['X1', 'X2', 'X3']
pc_labels = ['PC1', 'PC2', 'PC3']

for i, (a, b) in enumerate(pairs):
    
    ax[0, i].scatter(X[:, a], X[:, b], color='red', alpha=0.5)
    ax[0, i].set_xlabel(labels[a])
    ax[0, i].set_ylabel(labels[b])
    ax[0, i].set_title(f'Original data: {labels[a]} vs {labels[b]}')
    ax[0, i].grid(True, linestyle='--', alpha=0.6)
    ax[0, i].axis('equal')
    
    ax[1, i].scatter(X_reduced4plots[:, a], X_reduced4plots[:, b], color='blue', alpha=0.5)
    ax[1, i].set_xlabel(pc_labels[a])
    ax[1, i].set_ylabel(pc_labels[b])
    ax[1, i].set_title(f'PCA data: {pc_labels[a]} vs {pc_labels[b]}')
    ax[1, i].grid(True, linestyle='--', alpha=0.6)
    ax[1, i].axis('equal')

plt.tight_layout()
plt.show()
# Out:
# [-4.09414535e-16+0.j  1.95491111e+00+0.j  2.65662962e+01+0.j]
# [[ 1.00912484  1.04207937  3.06032906]
#  [ 1.04207937  9.65363279 11.73779154]
#  [ 3.06032906 11.73779154 17.85844967]]
#
# [1.96453709e-31 1.95491111e+00 2.65662962e+01]
# [[ 1.00912484  1.04207937  3.06032906]
#  [ 1.04207937  9.65363279 11.73779154]
#  [ 3.06032906 11.73779154 17.85844967]]
#
# Variability: [6.88798715e-33 6.85423688e-02 9.31457631e-01]
# From this it is clear that we have to remove the first entry to retain the 99% of total variance while we remove this feature
#
# [[ 0.0220435   0.12619789]
#  [-0.47086985  1.2842134 ]
#  [ 2.36977524  0.94800874]
#  ...
#  [-3.43819437 -1.08434987]
#  [ 1.65008364  0.13815717]
#  [ 5.89904985 -0.05297437]]

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
import numpy as np
import scipy.linalg as la
import matplotlib.pyplot as plt

N = 1000
x1 = np.random.normal(loc=0, scale=1, size=N)
x2 = x1 + np.random.normal(loc=0, scale=3, size=N)
x3 = 2*x1 + x2

stdlist = np.linspace(0.02, 0.20, 10)

for x in [x1,x2,x3]:
    noise = [np.random.normal(loc=0, scale=np.random.choice(stdlist)) for i in range(N)]
    x += noise

X = np.column_stack((x1, x2, x3))
X = X - np.mean(X, axis=0) # center the data on zero

# PCA via SVD
U, sigma, Vt = la.svd(X)
cov = (Vt @ np.diag(sigma) @ np.diag(sigma).T @ Vt.T)/(N-1)
variances = sigma**2/(N-1)
print(cov)
print(variances, '\n')

# dimensionality reduction
ratio = variances/np.sum(variances)
print(f'Variance Ratios: {ratio}\n')

Vt_reduced = Vt[:2, :]
X_reduced = X @ Vt_reduced.T
print(X_reduced)

# plot
X_reduced4plots = np.hstack((X_reduced, np.zeros((N,1))))

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(14,10))

pairs = [(0,1), (0,2), (1,2)]
labels = ['X1', 'X2', 'X3']
pc_labels = ['PC1', 'PC2', 'PC3']

for i, (a, b) in enumerate(pairs):
    
    ax[0, i].scatter(X[:, a], X[:, b], color='red', alpha=0.5)
    ax[0, i].set_xlabel(labels[a])
    ax[0, i].set_ylabel(labels[b])
    ax[0, i].set_title(f'Original data: {labels[a]} vs {labels[b]}')
    ax[0, i].grid(True, linestyle='--', alpha=0.6)
    ax[0, i].axis('equal')
    
    ax[1, i].scatter(X_reduced4plots[:, a], X_reduced4plots[:, b], color='blue', alpha=0.5)
    ax[1, i].set_xlabel(pc_labels[a])
    ax[1, i].set_ylabel(pc_labels[b])
    ax[1, i].set_title(f'PCA data: {pc_labels[a]} vs {pc_labels[b]}')
    ax[1, i].grid(True, linestyle='--', alpha=0.6)
    ax[1, i].axis('equal')

plt.tight_layout()
plt.show()
# Out:
# [[  1.04131681  -1.12479049   3.1892311 ]
#  [ -1.12479049   9.5978948  -11.91872014]
#  [  3.1892311  -11.91872014  18.42700746]]
# [2.71303460e+01 1.92017840e+00 1.56946594e-02]
#
# Variance Ratios: [9.33397837e-01 6.60622008e-02 5.39962193e-04]
#
# [[ -4.35640882  -0.15458391]
#  [ -2.20953414   0.82159909]
#  [ -2.98055917   1.75632202]
#  ...
#  [-10.6781582    0.88027696]
#  [  1.38611329   0.26454086]
#  [-15.79816157   0.13170508]]

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
# Out:
# --2025-12-12 15:20:13--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘/home/dghezzi/data/magic04.data.3’
#
# magic04.data.3          [       <=>          ]   1.41M   973KB/s    in 1.5s
#
# 2025-12-12 15:20:14 (973 KB/s) - ‘/home/dghezzi/data/magic04.data.3’ saved [1477391]
#
# --2025-12-12 15:20:14--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘/home/dghezzi/data/magic04.names.3’
#
# magic04.names.3         [ <=>                ]   5.27K  --.-KB/s    in 0s
#
# 2025-12-12 15:20:16 (41.0 MB/s) - ‘/home/dghezzi/data/magic04.names.3’ saved [5400]
